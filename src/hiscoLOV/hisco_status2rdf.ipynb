# %%
from rdflib import Graph, Namespace, RDF, Literal, RDFS
import csv, os

g = Graph()

HISCO = Namespace('http://data.socialhistory.org/vocab/hisco/')
STATUS  = Namespace('http://data.socialhistory.org/vocab/hisco/status/')
SKOS  = Namespace('http://www.w3.org/2004/02/skos/core#')

variable_name = 'statusCollection'
g.add((STATUS[variable_name], RDF.type, SKOS['Collection']))
g.add((STATUS[variable_name], RDFS.label, Literal('STATUS')))
g.add((STATUS[variable_name], SKOS.definition, Literal('STATUS is a subsidiary classification designed to reduce the loss '+
                                                            'of information caused by ISCO68\'s failure to accomodate residual ' +
                                                            'information about employment status, educational qualifications, ' + 
                                                            'and social position.')))


g.bind('hisco', HISCO)
g.bind('status', STATUS)
g.bind('skos', SKOS)

default_path = "/Users/RichardZ/Dropbox/II/projects/clariah/sdh/basecamp/Files/Files attached directly to project/Files attached directly to project (1)/"
os.chdir(default_path)
hdf = open('./data2rdf/hisco/status.csv')
hisco = csv.reader(hdf)

next(hisco)

for row in hisco:
    hisco_status = row[0]
    hisco_status_label = row[1]

    g.add((STATUS[hisco_status], RDF.type, SKOS['Concept']))
    g.add((STATUS[hisco_status], SKOS['inScheme'], HISCO['hiscoScheme']))
    g.add((STATUS[hisco_status], SKOS['member'], HISCO[variable_name]))  
    g.add((STATUS[hisco_status], SKOS['prefLabel'], Literal(hisco_status_label,'en')))

print g.serialize(format='turtle')

with open('./rdf/hisco/hisco_status.ttl','w') as out:
    g.serialize(out, format='turtle')
# Out:
# @prefix hisco: <http://data.socialhistory.org/vocab/hisco/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix status: <http://data.socialhistory.org/vocab/hisco/status/> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://data.socialhistory.org/vocab/hisco/status/11> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Owner, proprietor"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/12> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Lease-holder, share-cropper"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/13> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Poor"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/21> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Master"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/22> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Journeyman"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/23> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Apprentice, learner"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/24> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Artisan"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/31> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Principal"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/32> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "'Worker'"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/33> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Subordinate"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/34> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Serfs and Slaves"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/41> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Student"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/42> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Graduate"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/51> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Nobility"@en .
#
# <http://data.socialhistory.org/vocab/hisco/status/52> a skos:Concept ;
#     skos:inScheme hisco:hiscoScheme ;
#     skos:member hisco:statusCollection ;
#     skos:prefLabel "Prestige titles"@en .
#
# status:statusCollection a skos:Collection ;
#     rdfs:label "STATUS" ;
#     skos:definition "STATUS is a subsidiary classification designed to reduce the loss of information caused by ISCO68's failure to accomodate residual information about employment status, educational qualifications, and social position." .
